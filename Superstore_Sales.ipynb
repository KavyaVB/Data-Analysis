# %%
# Import basic libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Load data
data=pd.read_csv("SampleSuperstore.csv")

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
# Null vals
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# Sum of duplicate vals
data.duplicated().sum()
# Out:
# 17

# %%
data.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
# Rename index 
data.index.rename("ID",inplace=True)

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# ID
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# Duplicate cols
duplicates=data[data.duplicated()]
duplicates
# Out:
#            Ship Mode      Segment        Country           City         State  \
# ID
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 3406  Standard Class  Home Office  United States       Columbus          Ohio
# 3670  Standard Class     Consumer  United States          Salem        Oregon
# 4117  Standard Class     Consumer  United States    Los Angeles    California
# 4553  Standard Class     Consumer  United States  San Francisco    California
# 5905        Same Day  Home Office  United States  San Francisco    California
# 6146  Standard Class    Corporate  United States  San Francisco    California
# 6334  Standard Class     Consumer  United States  New York City      New York
# 6357  Standard Class    Corporate  United States        Seattle    Washington
# 7608  Standard Class     Consumer  United States  San Francisco    California
# 7735  Standard Class    Corporate  United States        Seattle    Washington
# ...

# %%
# Descriptive Analysis
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# Total sales
data['Sales'].sum()
# Out:
# 2297200.8603000003

# %%
data[data['Region']=='East']
# Out:
#            Ship Mode   Segment        Country          City         State  \
# ID
# 23      Second Class  Consumer  United States  Philadelphia  Pennsylvania
# 27    Standard Class  Consumer  United States  Philadelphia  Pennsylvania
# 28    Standard Class  Consumer  United States  Philadelphia  Pennsylvania
# 29    Standard Class  Consumer  United States  Philadelphia  Pennsylvania
# 30    Standard Class  Consumer  United States  Philadelphia  Pennsylvania
# ...              ...       ...            ...           ...           ...
# 9968  Standard Class  Consumer  United States    Plainfield    New Jersey
# 9969  Standard Class  Consumer  United States    Plainfield    New Jersey
# 9981     First Class  Consumer  United States     Fairfield          Ohio
# 9984  Standard Class  Consumer  United States    Long Beach      New York
# 9985  Standard Class  Consumer  United States    Long Beach      New York
#
# ...

# %%
data[data['Quantity']>10]
# Out:
#            Ship Mode      Segment        Country           City         State  \
# ID
# 113     Second Class     Consumer  United States       Columbus          Ohio
# 139   Standard Class     Consumer  United States      Roseville    California
# 147   Standard Class    Corporate  United States       Franklin     Wisconsin
# 251   Standard Class     Consumer  United States      San Diego    California
# 342     Second Class    Corporate  United States   Philadelphia  Pennsylvania
# ...              ...          ...            ...            ...           ...
# 9732  Standard Class    Corporate  United States        Hampton      Virginia
# 9882     First Class     Consumer  United States      Woodstock       Georgia
# 9895  Standard Class     Consumer  United States        Chicago      Illinois
# 9941  Standard Class     Consumer  United States  San Francisco    California
# 9979  Standard Class  Home Office  United States    Los Angeles    California
#
# ...

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data['Quantity'].max()
# Out:
# 14

# %%
# Frequent customers

data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
# High-value customers

data[data['Segment']=='Consumer']['Quantity'].sum()
# Out:
# 19521

# %%
data[data['Segment']=='Corporate']['Quantity'].sum()
# Out:
# 11608

# %%
data[data['Segment']=='Home Office']['Quantity'].sum()
# Out:
# 6744

# %%
# Characteristics of Consumer segment

data[data['Segment']=='Consumer'].describe()
# Out:
#         Postal Code      Category         Sales     Quantity     Discount  \
# count   5191.000000  5.191000e+03   5191.000000  5191.000000  5191.000000
# mean   55649.895781  2.297201e+06    223.733644     3.760547     0.158141
# std    31986.471601  0.000000e+00    585.516175     2.206898     0.207485
# min     1453.000000  2.297201e+06      0.444000     1.000000     0.000000
# 25%    23464.000000  2.297201e+06     17.264000     2.000000     0.000000
# 50%    60201.000000  2.297201e+06     53.720000     3.000000     0.200000
# 75%    90008.000000  2.297201e+06    206.106000     5.000000     0.200000
# max    99301.000000  2.297201e+06  13999.960000    14.000000     0.800000
#
#             Profit
# count  5191.000000
# mean     25.836873
# std     242.594020
# min   -6599.978000
# 25%       1.583550
# 50%       8.375400
# 75%      28.606700
# max    6719.980800

# %%
# Characteristics of Corporate Segment

data[data['Segment']=='Corporate'].describe()
# Out:
#         Postal Code      Category         Sales     Quantity     Discount  \
# count   3020.000000  3.020000e+03   3020.000000  3020.000000  3020.000000
# mean   54482.228477  2.297201e+06    233.823300     3.843709     0.158228
# std    32313.056957  4.657384e-10    599.410408     2.238676     0.206548
# min     1453.000000  2.297201e+06      0.556000     1.000000     0.000000
# 25%    22153.000000  2.297201e+06     17.469000     2.000000     0.000000
# 50%    53209.000000  2.297201e+06     56.540000     3.000000     0.200000
# 75%    90004.000000  2.297201e+06    212.895000     5.000000     0.200000
# max    99207.000000  2.297201e+06  17499.950000    14.000000     0.800000
#
#             Profit
# count  3020.000000
# mean     30.456667
# std     231.986266
# min   -3839.990400
# 25%       1.928400
# 50%       8.694000
# 75%      29.843500
# max    8399.976000

# %%
# Characteristics of Home office Segment

data[data['Segment']=='Home Office'].describe()
# Out:
#         Postal Code      Category         Sales     Quantity     Discount  \
# count   1783.000000  1.783000e+03   1783.000000  1783.000000  1783.000000
# mean   55051.998317  2.297201e+06    240.972041     3.782389     0.147128
# std    31858.414595  4.657919e-10    755.516379     2.254260     0.203119
# min     1040.000000  2.297201e+06      0.990000     1.000000     0.000000
# 25%    23464.000000  2.297201e+06     17.045000     2.000000     0.000000
# 50%    55113.000000  2.297201e+06     52.440000     3.000000     0.000000
# 75%    90004.000000  2.297201e+06    210.906000     5.000000     0.200000
# max    99207.000000  2.297201e+06  22638.480000    14.000000     0.800000
#
#             Profit
# count  1783.000000
# mean     33.818664
# std     212.381482
# min   -3399.980000
# 25%       1.984250
# 50%       9.102000
# 75%      31.559850
# max    3919.988800

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
data[data['Category']=='Office Supplies']['Sales'].sum()
# Out:
# 719047.032

# %%
data[data['Category']=='Furniture']['Sales'].sum()
# Out:
# 741999.7953

# %%
# Top Selling Category with highest sales

data[data['Category']=='Technology']['Sales'].sum()
# Out:
# 836154.033

# %%
data['Segment'].describe()
# Out:
# count         9994
# unique           3
# top       Consumer
# freq          5191
# Name: Segment, dtype: object
